# %%
import pandas as pd
import plotly.express as px
from sklearn.preprocessing import LabelBinarizer
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import warnings
warnings.filterwarnings('ignore')

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
downloaded = drive.CreateFile({'id': '1enm89rVnYJAzZFUHDnqVY_5TWRsE3pEF'})
downloaded.GetContentFile('magnetico.csv')
downloaded = drive.CreateFile({'id': '1XOUKapXo737TW6fptVRArg5LjpX7SB8J'})
downloaded.GetContentFile('vento.csv')

# %%
#Aqui nós iremos armazenar o dataset que baixamos antes para poder mostrar e manipular ele
df_vento = pd.read_csv('vento.csv', on_bad_lines='skip')
df_mag = pd.read_csv('magnetico.csv', on_bad_lines='skip')

# %%
#Aqui nós iremos verificar quais colunas temos e quais precisão de um processamento
df_vento.head()
# Out:
#   EPOCH_yyyy-mm-ddThh:mm:ss.sssZ     B_nT
# 0       2022-09-17T00:00:00.073Z  5.96360
# 1       2022-09-17T00:00:00.165Z  5.95045
# 2       2022-09-17T00:00:00.257Z  5.93664
# 3       2022-09-17T00:00:00.349Z  5.92131
# 4       2022-09-17T00:00:00.441Z  5.92786

# %%
#Aqui nós iremos verificar quais colunas temos e quais precisão de um processamento
df_mag.head()
# Out:
#   EPOCH_yyyy-mm-ddThh:mm:ss.sssZ  <|B|>_nT
# 0       2022-07-10T23:00:00.000Z     3.059
# 1       2022-07-11T00:00:00.000Z     2.448
# 2       2022-07-11T01:00:00.000Z     3.190
# 3       2022-07-11T02:00:00.000Z     3.254
# 4       2022-07-11T03:00:00.000Z     2.900

# %%
#Aqui nós iremos fazer uma análise estatística para ver quais suposições podemos tirar dos primeiros dados
df_mag.describe()
# Out:
#         <|B|>_nT
# count  25.000000
# mean    8.385600
# std     4.004334
# min     2.448000
# 25%     4.886000
# 50%     9.412000
# 75%    11.130000
# max    16.035000
